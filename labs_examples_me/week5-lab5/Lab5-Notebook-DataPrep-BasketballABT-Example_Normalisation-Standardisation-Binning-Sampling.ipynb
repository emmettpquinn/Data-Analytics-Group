# %% [markdown]
# # Lab5: Data Preparation steps: practicing feature Normalisation, feature Binning and row Sampling
#
# This lab uses the file `BasketballTeam.csv` to show common data prep steps on a small dataset.
# Focus on numeric features for normalisation and standardisation, then apply binning and sampling.
# Several plots are saved to files to document the changes.
#
# **Notes**
# - The dataset contains player-level rows with mixed numeric and categorical fields.
# - `ID` is treated as an identifier and excluded from numeric summaries.
# - `ShoeSponsor` is used later as the example target for sampling.

# %%
# Good tutorial on pandas: http://pandas.pydata.org/pandas-docs/stable/10min.html
# Pandas Cookbook: http://pandas.pydata.org/pandas-docs/stable/tutorials.html
# Another good resource for pandas: http://chrisalbon.com/python/pandas_dataframe_importing_csv.htm

#Import the required packages
#Import package pandas for data analysis
import pandas as pd

# Import package numpy for numeric computing
import numpy as np

# Import package matplotlib for visualisation/plotting
import matplotlib.pyplot as plt

#For showing plots directly in the notebook run the command below
# %matplotlib inline

# For saving multiple plots into a single pdf file
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split

# %%
# Reading from a csv file, into a data frame
# Can set parameters to remove white space from the beginning and end of column names
# Read more about .read_csv() here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
df = pd.read_csv('BasketballTeam.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
# Show data frame first few rows
df.head(10)
# Out:
#    ID Position  Height  Weight  Sponsorship Earnings Shoe Sponsor  \
# 0   1  forward     192     218                   561          yes
# 1   2   center     218     251                    60           no
# 2   3  forward     197     221                  1312           no
# 3   4  forward     192     219                  1359           no
# 4   5  forward     198     223                   362          yes
# 5   6    guard     166     188                  1536          yes
# 6   7  forward     195     221                   694           no
# 7   8    guard     182     199                  1678          yes
# 8   9    guard     189     199                   385          yes
# 9  10  forward     205     232                  1416           no
#
#   Career Stage  Age
# 0      veteran   29
# 1   mid-career   35
# 2       rookie   22
# 3       rookie   22
# 4      veteran   29
# 5       rookie   21
# 6      veteran   25
# 7       rookie   21
# 8   mid-career   27
# 9       rookie   24

# %%
# Check how many rows and columns this dataframe has
df.shape
# Out:
# (30, 8)

# %%
# Show the data types in each column.
# int64 and float64 are numeric columns.
# The pandas type 'object' stands for Python strings
# Columns mixing numbers and characters are automatically converted to type 'object'.
# Some of the type 'object' columns may be more appropriate as continuous or as categorical types.
# We first explore the data, then decide which columns should be treated as 'continuous' and which 
# should be treated as 'categorical'.
# You can see below that some columns are wrongly set to continuous types, e.g., ID.
df.dtypes
# Out:
# ID                       int64
# Position                object
# Height                   int64
# Weight                   int64
# Sponsorship Earnings     int64
# Shoe Sponsor            object
# Career Stage            object
# Age                      int64
# dtype: object

# %%
# Look at column names. Some have spaces in or after the name, e.g., 'Insurance Type '.
df.columns
# Out:
# Index(['ID', 'Position', 'Height', 'Weight', 'Sponsorship Earnings',
#        'Shoe Sponsor', 'Career Stage', 'Age'],
#       dtype='object')

# %%
# Clean the column names to remove white space after the name or in the name
df.columns = df.columns.str.replace(' ', '')
#df.columns = df.columns.str.replace(' ', '_')

# %%
# Turn the feature ID into type 'object' so it is not used during descriptive stats
df['ID'] = df['ID'].astype('object')
df.dtypes
# Out:
# ID                     object
# Position               object
# Height                  int64
# Weight                  int64
# SponsorshipEarnings     int64
# ShoeSponsor            object
# CareerStage            object
# Age                     int64
# dtype: object

# %%
# Descriptive stats for continuous features
# Transpose the table so it looks like the table in the lecture/textbook
# One feature per row, stats in the columns
# The 'count' column shows how many rows have data for that feature.
# We can see that Num Soft Tissue only has 490 rows defined (out of 500 rows total), so 10 rows are 
# missing this value.
# This table does not show the cardinality and the %Missing columns.
# We compute them below.
df.describe().T
# Out:
#                      count        mean         std    min     25%    50%  \
# Height                30.0  191.100000   13.606160  158.0  185.00  192.0
# Weight                30.0  215.033333   19.801573  183.0  199.25  218.0
# SponsorshipEarnings   30.0  814.400000  557.700241   12.0  367.75  671.0
# Age                   30.0   26.400000    4.206727   19.0   22.25   27.0
#
#                          75%     max
# Height                198.00   218.0
# Weight                229.75   251.0
# SponsorshipEarnings  1347.25  1855.0
# Age                    29.00    35.0

# %%
#Keep only the numeric features.
numeric_columns = df.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['Height', 'Weight', 'SponsorshipEarnings', 'Age'], dtype='object')

# %%
# Select only the numeric features
df[numeric_columns].head()
# Out:
#    Height  Weight  SponsorshipEarnings  Age
# 0     192     218                  561   29
# 1     218     251                   60   35
# 2     197     221                 1312   22
# 3     192     219                 1359   22
# 4     198     223                  362   29

# %%
# A way to get the number of unique values for all features
df.nunique()
# Out:
# ID                     30
# Position                3
# Height                 23
# Weight                 21
# SponsorshipEarnings    30
# ShoeSponsor             2
# CareerStage             3
# Age                    13
# dtype: int64

# %%
#Missing data
#http://pandas.pydata.org/pandas-docs/stable/missing_data.html
# When summing data, NA (missing) values will be treated as zero
# If the data are all NA, the result will be NA
# Methods like cumsum and cumprod ignore NA values, but preserve them in the resulting arrays

#Missing data all features
df.isnull().sum()
# Out:
# ID                     0
# Position               0
# Height                 0
# Weight                 0
# SponsorshipEarnings    0
# ShoeSponsor            0
# CareerStage            0
# Age                    0
# dtype: int64

# %%
#Select all columns of type 'object'
object_columns = df.select_dtypes(['object']).columns
object_columns
# Out:
# Index(['ID', 'Position', 'ShoeSponsor', 'CareerStage'], dtype='object')

# %%
#Convert selected columns to type 'category'
for column in object_columns.drop('ID'):
    df[column] = df[column].astype('category')
df.dtypes
# Out:
# ID                       object
# Position               category
# Height                    int64
# Weight                    int64
# SponsorshipEarnings       int64
# ShoeSponsor            category
# CareerStage            category
# Age                       int64
# dtype: object

# %%
numeric_columns = df.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['Height', 'Weight', 'SponsorshipEarnings', 'Age'], dtype='object')

# %%
#Look at the categorical features only
category_columns = df.select_dtypes(['category']).columns
category_columns
# Out:
# Index(['Position', 'ShoeSponsor', 'CareerStage'], dtype='object')

# %%
# Descriptive stats for categorical features only.
df[category_columns].describe().T
# Out:
#             count unique         top freq
# Position       30      3     forward   12
# ShoeSponsor    30      2          no   16
# CareerStage    30      3  mid-career   12

# %%
#Print the number of duplicates, without the original rows that were duplicated
print('Number of duplicate (excluding first) rows in the table is: ', df.duplicated().sum())

# Check for duplicate rows. 
# Use "keep=False" to mark all duplicates as true, including the original rows that were duplicated.
print('Number of duplicate rows (including first) in the table is:', df[df.duplicated(keep=False)].shape[0])
# Out:
# Number of duplicate (excluding first) rows in the table is:  0
# Number of duplicate rows (including first) in the table is: 0

# %%
# Check for duplicate columns
#First transpose the df so columns become rows, then apply the same check as above
dfT = df.T
print("Number of duplicate (excluding first) columns in the table is: ", dfT.duplicated().sum())
print("Number of duplicate (including first) columns in the table is: ",  dfT[dfT.duplicated(keep=False)].shape[0])
# Out:
# Number of duplicate (excluding first) columns in the table is:  0
# Number of duplicate (including first) columns in the table is:  0

# %% [markdown]
# # Normalisation of numeric features
#
# We keep only numeric columns in `df_cont` before scaling.
# - Min-max normalisation rescales values to the range [0, 1].
# - Standardisation converts each column to a z-score with mean 0 and standard deviation 1.
# Use these steps only for continuous features, not categories.
#
# **Notes**
# - In this dataset, numeric columns include measures like Height, Weight, Age, and SponsorshipEarnings.
# - Scaling is applied per column, so each feature keeps its relative ordering.
# - Categorical fields such as ShoeSponsor are excluded from scaling.

# %%
# Look once again at the summary stats table for numeric features
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html
df[numeric_columns].describe().T
# Out:
#                      count        mean         std    min     25%    50%  \
# Height                30.0  191.100000   13.606160  158.0  185.00  192.0
# Weight                30.0  215.033333   19.801573  183.0  199.25  218.0
# SponsorshipEarnings   30.0  814.400000  557.700241   12.0  367.75  671.0
# Age                   30.0   26.400000    4.206727   19.0   22.25   27.0
#
#                          75%     max
# Height                198.00   218.0
# Weight                229.75   251.0
# SponsorshipEarnings  1347.25  1855.0
# Age                    29.00    35.0

# %%
#Only keep numeric features
df_cont = df[numeric_columns]
df_cont.head()
# Out:
#    Height  Weight  SponsorshipEarnings  Age
# 0     192     218                  561   29
# 1     218     251                   60   35
# 2     197     221                 1312   22
# 3     192     219                 1359   22
# 4     198     223                  362   29

# %%
#Range normalise all numeric columns
df_norm = (df_cont - df_cont.min()) / (df_cont.max() - df_cont.min())
df_norm.head()
# Out:
#      Height    Weight  SponsorshipEarnings     Age
# 0  0.566667  0.514706             0.297884  0.6250
# 1  1.000000  1.000000             0.026044  1.0000
# 2  0.650000  0.558824             0.705372  0.1875
# 3  0.566667  0.529412             0.730874  0.1875
# 4  0.666667  0.588235             0.189908  0.6250

# %%
# Standardise all numeric columns
df_st = (df_cont - df_cont.mean()) / df_cont.std()
df_st.head()
# Out:
#      Height    Weight  SponsorshipEarnings       Age
# 0  0.066147  0.149820            -0.454366  0.618058
# 1  1.977046  1.816354            -1.352698  2.044345
# 2  0.433627  0.301323             0.892236 -1.045944
# 3  0.066147  0.200321             0.976510 -1.045944
# 4  0.507123  0.402325            -0.811188  0.618058

# %% [markdown]
# ## Visualisations of features before and after normalisation
#
# We compare histogram shapes before and after scaling to see how distributions change.
# Each plot is saved as a PNG so you can include it in a report.
#
# **What to observe**
# - Compare the spread before vs after scaling for features like Height and Weight.
# - Check whether skewness changes or only the scale, especially for SponsorshipEarnings.
# - Look for features with extreme ranges that dominate the raw plots.

# %%
#http://pandas.pydata.org/pandas-docs/stable/visualization.html
# We can plot the histogram of all numeric features at the same time.
plt.figure()
df_cont.hist(figsize=(10, 10), xrot = 45)
# We can save the plot into a file as shown below.
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-histograms-1-1.png')

# %%
# Histograms of normalised features
plt.figure()
df_norm.hist(figsize=(10, 10), xrot = 45)
# We can save the plot into a file as shown below.
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-normalised-histograms-1-1.png')

# %%
# Histograms of standardised features
plt.figure()
df_st.hist(figsize=(10, 10), xrot = 45)
# We can save the plot into a file as shown below.
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-standardised-histograms-1-1.png')

# %% [markdown]
# # What happens to normalised features if we have outliers?
#
# We add a single extreme value to see how min-max scaling compresses the other values.
# Standardisation is also affected, but typically less than min-max scaling.
#
# **What to observe**
# - The outlier is added to SponsorshipEarnings, so that column changes the most.
# - Min-max scaling can squash most values into a narrow band.
# - Standardised plots still show the outlier but preserve more structure.

# %%
#Lets add one outlier on SponsorshipEarnings to check effect on normalisation/standardisation of columns

df_outliers = pd.DataFrame({"Height":[200], 
                            "Weight":[200],
                            "SponsorshipEarnings":[10000],
                          "Age":[35]}) 

df_out = pd.concat([df_cont, df_outliers], ignore_index = True) 
#print(df_cont.shape)
#print(df_out.shape)
# copy df_cont to another data frame and add an outlier row to the new dataframe

# %%
plt.figure()
df_out.hist(figsize=(10, 10), xrot = 45)
# We can save the plot into a file as shown below.
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-histograms-outlier-1-1.png')

# %%
#Range normalise all numeric columns
df_out_norm = (df_out - df_out.min()) / (df_out.max() - df_out.min())
df_out_norm
# Out:
#       Height    Weight  SponsorshipEarnings     Age
# 0   0.566667  0.514706             0.054966  0.6250
# 1   1.000000  1.000000             0.004806  1.0000
# 2   0.650000  0.558824             0.130156  0.1875
# 3   0.566667  0.529412             0.134862  0.1875
# 4   0.666667  0.588235             0.035042  0.6250
# 5   0.133333  0.073529             0.152583  0.1250
# 6   0.616667  0.558824             0.068282  0.3750
# 7   0.400000  0.235294             0.166800  0.1250
# 8   0.516667  0.235294             0.037345  0.5000
# 9   0.783333  0.720588             0.140569  0.3125
# 10  0.800000  0.926471             0.030236  0.6250
# 11  0.450000  0.352941             0.148678  0.2500
# 12  0.233333  0.000000             0.137265  0.3125
# 13  0.183333  0.000000             0.102323  0.3125
# 14  0.450000  0.205882             0.016620  0.6250
# 15  0.950000  0.720588             0.042251  0.6875
# 16  0.000000  0.014706             0.015018  0.6250
# 17  0.533333  0.352941             0.063676  0.5000
# 18  0.616667  0.764706             0.046956  0.5625
# 19  0.566667  0.250000             0.041550  0.8125
# 20  0.733333  0.544118             0.053064  0.7500
# 21  0.433333  0.441176             0.000000  0.8125
# 22  0.533333  0.470588             0.116840  0.1875
# 23  0.333333  0.147059             0.106728  0.1250
# 24  0.450000  0.250000             0.020124  0.7500
# 25  0.550000  0.514706             0.184521  0.0000
# 26  0.633333  0.764706             0.003504  0.8125
# 27  0.666667  0.558824             0.139868  0.1875
# 28  0.816667  0.941176             0.105427  0.5000
# 29  0.716667  0.897059             0.110032  0.3750
# 30  0.700000  0.250000             1.000000  1.0000

# %%
# Histograms of normalised features
plt.figure()
df_out_norm.hist(figsize=(10, 10), xrot = 45)
# We can save the plot into a file as shown below.
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-normalised-histograms-outlier-1-1.png')

# %%
# Standardise all numeric columns in the dataframe with 1 outlier
df_out_st = (df_out - df_out.mean()) / df_out.std()
df_out_st
# Out:
#       Height    Weight  SponsorshipEarnings       Age
# 0   0.045492  0.175609            -0.316194  0.526062
# 1   1.975331  1.854563            -0.604371  1.885057
# 2   0.416615  0.328241             0.115783 -1.059431
# 3   0.045492  0.226487             0.142817 -1.059431
# 4   0.490840  0.429996            -0.430660  0.526062
# 5  -1.884346 -1.350713             0.244628 -1.285931
# 6   0.268166  0.328241            -0.239693 -0.379934
# 7  -0.696753 -0.791062             0.326307 -1.285931
# 8  -0.177181 -0.791062            -0.417430  0.073064
# 9   1.010412  0.887893             0.175604 -0.606433
# 10  1.084636  1.600176            -0.458270  0.526062
# 11 -0.474079 -0.384042             0.222195 -0.832932
# 12 -1.438998 -1.605100             0.156622 -0.606433
# 13 -1.661672 -1.605100            -0.044124 -0.606433
# 14 -0.474079 -0.892816            -0.536497  0.526062
# 15  1.752657  0.887893            -0.389245  0.752562
# 16 -2.478142 -1.554223            -0.545700  0.526062
# 17 -0.102957 -0.384042            -0.266152  0.073064
# 18  0.268166  1.040525            -0.362211  0.299563
# 19  0.045492 -0.740184            -0.393272  1.205560
# 20  0.787738  0.277364            -0.327123  0.979061
# 21 -0.548304 -0.078778            -0.631981  1.205560
# 22 -0.102957  0.022977             0.039281 -1.059431
# 23 -0.993651 -1.096326            -0.018815 -1.285931
# 24 -0.474079 -0.740184            -0.516365  0.979061
# 25 -0.028732  0.175609             0.428118 -1.738929
# 26  0.342391  1.040525            -0.611849  1.205560
# 27  0.490840  0.328241             0.171577 -1.059431
# 28  1.158861  1.651054            -0.026292  0.073064
# 29  0.713513  1.498422             0.000167 -0.379934
# 30  0.639289 -0.740184             5.113143  1.885057

# %%
# Histograms of standardised features
plt.figure()
df_out_st.hist(figsize=(10, 10), xrot = 45)
# We can save the plot into a file as shown below.
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-standardised-histograms-outlier-1-1.png')

# %% [markdown]
# ## Boxplots before and after scaling
#
# **What to observe**
# - Outliers are easier to spot in the raw boxplots for SponsorshipEarnings.
# - Normalisation compresses the boxes, especially with extreme values.
# - Standardisation keeps relative differences while changing the scale.

# %%
#With outliers the Earnings plot looks squashed
df_out[numeric_columns].plot(kind='box', subplots=True, figsize=(10,10), layout=(2,2), sharex=False, sharey=False, fontsize=16)
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-boxplots_all_1-1.pdf')

# %%
#Without outliers easier to see what happens in Earnings
df_cont.plot(kind='box', subplots=True, figsize=(10,10), layout=(2,2), sharex=False, sharey=False, fontsize=16)
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-normalised-boxplots_all_1-1.pdf')

# %%
df_norm.plot(kind='box', subplots=True, figsize=(10,10), layout=(2,2), sharex=False, sharey=False, fontsize=16)
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-normalised-boxplots_all_1-1.pdf')

# %%
df_st.plot(kind='box', subplots=True, figsize=(10,10), layout=(2,2), sharex=False, sharey=False, fontsize=16)
plt.savefig('BasketballTeam-DataQualityReport-NumericFeatures-standardised-boxplots_all_1-1.pdf')

# %% [markdown]
# # Binning of numeric features
#
# Binning converts a continuous feature into discrete groups.
# `qcut` creates bins with (roughly) equal numbers of rows per bin, while `cut` uses equal-width bins.
# We store the new binned columns in `quantile_ex_q4` and `quantile_ex_q10` for comparison.
#
# **Notes**
# - SponsorshipEarnings is used here to create earnings bands.
# - Quantile binning ensures similar counts per bin, which can help with imbalanced ranges.
# - New bin columns can be treated as categorical features for modeling.
#
# Also see example here: https://pbpython.com/pandas-qcut-cut.html

# %%
df_cont.head()
# Out:
#    Height  Weight  SponsorshipEarnings  Age
# 0     192     218                  561   29
# 1     218     251                   60   35
# 2     197     221                 1312   22
# 3     192     219                 1359   22
# 4     198     223                  362   29

# %%
df['SponsorshipEarnings'].describe()
# Out:
# count      30.000000
# mean      814.400000
# std       557.700241
# min        12.000000
# 25%       367.750000
# 50%       671.000000
# 75%      1347.250000
# max      1855.000000
# Name: SponsorshipEarnings, dtype: float64

# %%
# Bins obtained for the SponsorshipEarnings feature using 4 bins and the qcut function
pd.qcut(df['SponsorshipEarnings'], q=4).value_counts()
# Out:
# SponsorshipEarnings
# (11.999, 367.75]     8
# (1347.25, 1855.0]    8
# (367.75, 671.0]      7
# (671.0, 1347.25]     7
# Name: count, dtype: int64

# %%
# See the binned feature
pd.qcut(df['SponsorshipEarnings'], q=4)
# Out:
# 0       (367.75, 671.0]
# 1      (11.999, 367.75]
# 2      (671.0, 1347.25]
# 3     (1347.25, 1855.0]
# 4      (11.999, 367.75]
# 5     (1347.25, 1855.0]
# 6      (671.0, 1347.25]
# 7     (1347.25, 1855.0]
# 8       (367.75, 671.0]
# 9     (1347.25, 1855.0]
# 10     (11.999, 367.75]
# 11    (1347.25, 1855.0]
# 12    (1347.25, 1855.0]
# 13     (671.0, 1347.25]
# 14     (11.999, 367.75]
# 15      (367.75, 671.0]
# 16     (11.999, 367.75]
# 17      (367.75, 671.0]
# 18      (367.75, 671.0]
# 19      (367.75, 671.0]
# 20      (367.75, 671.0]
# 21     (11.999, 367.75]
# 22     (671.0, 1347.25]
# 23     (671.0, 1347.25]
# 24     (11.999, 367.75]
# 25    (1347.25, 1855.0]
# 26     (11.999, 367.75]
# 27    (1347.25, 1855.0]
# 28     (671.0, 1347.25]
# 29     (671.0, 1347.25]
# Name: SponsorshipEarnings, dtype: category
# Categories (4, interval[float64, right]): [(11.999, 367.75] < (367.75, 671.0] < (671.0, 1347.25] < (1347.25, 1855.0]]

# %%
df['quantile_ex_q4'] = pd.qcut(df['SponsorshipEarnings'], q=4)
df['quantile_ex_q10'] = pd.qcut(df['SponsorshipEarnings'], q=10, precision=0)

df.head()
# Out:
#   ID Position  Height  Weight  SponsorshipEarnings ShoeSponsor CareerStage  \
# 0  1  forward     192     218                  561         yes     veteran
# 1  2   center     218     251                   60          no  mid-career
# 2  3  forward     197     221                 1312          no      rookie
# 3  4  forward     192     219                 1359          no      rookie
# 4  5  forward     198     223                  362         yes     veteran
#
#    Age     quantile_ex_q4   quantile_ex_q10
# 0   29    (367.75, 671.0]    (518.0, 671.0]
# 1   35   (11.999, 367.75]     (11.0, 152.0]
# 2   22   (671.0, 1347.25]  (1219.0, 1388.0]
# 3   22  (1347.25, 1855.0]  (1219.0, 1388.0]
# 4   29   (11.999, 367.75]    (294.0, 414.0]

# %%
df['quantile_ex_q10'].value_counts()
# Out:
# quantile_ex_q10
# (11.0, 152.0]       3
# (152.0, 294.0]      3
# (294.0, 414.0]      3
# (414.0, 518.0]      3
# (518.0, 671.0]      3
# (671.0, 1070.0]     3
# (1070.0, 1219.0]    3
# (1219.0, 1388.0]    3
# (1388.0, 1501.0]    3
# (1501.0, 1855.0]    3
# Name: count, dtype: int64

# %% [markdown]
# # Sampling
#
# We start with a simple random sample and then create train/test splits.
# Stratified sampling preserves the class proportions of the target feature.
# Later, we create an intentionally imbalanced target to show how stratification helps.
#
# **Notes**
# - `ShoeSponsor` is the target label for the balanced examples.
# - Train/test splits use 70/30 to keep results comparable across runs.
# - The unbalanced example shows why stratification matters for rare classes.

# %%
# Random sampling to extract 1 single subsample
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html
df_random_sample = df.sample(frac=0.3, replace=False, random_state=1)
df_random_sample.to_csv('BasketballTeam-random-30perc-sample.csv', index=False)
df_random_sample
# Out:
#     ID Position  Height  Weight  SponsorshipEarnings ShoeSponsor CareerStage  \
# 17  18    guard     190     207                  648         yes  mid-career
# 21  22  forward     184     213                   12          no  mid-career
# 10  11   center     206     246                  314          no  mid-career
# 19  20    guard     192     200                  427         yes  mid-career
# 14  15    guard     185     197                  178         yes  mid-career
# 20  21  forward     202     220                  542          no  mid-career
# 26  27   center     196     235                   47          no     veteran
# 3    4  forward     192     219                 1359          no      rookie
# 24  25    guard     185     200                  213         yes  mid-career
#
#     Age     quantile_ex_q4   quantile_ex_q10
# 17   27    (367.75, 671.0]    (518.0, 671.0]
# 21   32   (11.999, 367.75]     (11.0, 152.0]
# 10   29   (11.999, 367.75]    (294.0, 414.0]
# 19   32    (367.75, 671.0]    (414.0, 518.0]
# 14   29   (11.999, 367.75]    (152.0, 294.0]
# 20   31    (367.75, 671.0]    (518.0, 671.0]
# 26   32   (11.999, 367.75]     (11.0, 152.0]
# 3    22  (1347.25, 1855.0]  (1219.0, 1388.0]
# 24   31   (11.999, 367.75]    (152.0, 294.0]

# %%
#Random sampling to extract 2 subsamples, one for training and one for testing
features = df.columns[df.columns != 'ShoeSponsor']

#Separate the input features and the target feature
X = df[features]
y = df.ShoeSponsor

#print("\nDescriptive features in X:\n", X)
#print("\nTarget feature in y:\n", y)

# Random sample from full df, keep 70% sample for train and remaining 30% sample for test
# If we want to always get the same sample, set random_state=1.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

#print("\nTraining data:\n", pd.concat([X_train, y_train], axis=1))
#print("\nTest data:\n", pd.concat([X_test, y_test], axis=1))

print("\nTarget feature ShoeSponsor total dataset counts:\n\n", y.value_counts())
print("\nTraining data ShoeSponsor counts:\n", y_train.value_counts())
print("\nTest data ShoeSponsor counts:\n", y_test.value_counts())
# Out:
# Target feature ShoeSponsor total dataset counts:
#
#  ShoeSponsor
# no     16
# yes    14
# Name: count, dtype: int64
#
# Training data ShoeSponsor counts:
#  ShoeSponsor
# no     11
# yes    10
# Name: count, dtype: int64
#
# Test data ShoeSponsor counts:
#  ShoeSponsor
# no     5
# yes    4
# Name: count, dtype: int64

# %%
# Stratified sampling
features = df.columns[df.columns != 'ShoeSponsor']

X = df[features]
y = df.ShoeSponsor

#print("\nDescriptive features in X:\n", X)
#print("\nTarget feature in y:\n", y)

# Stratify sample wrt column ShoeSponsor (stratify=y) so the train/test samples have a distribution 
# representative of the full sample for the ShoeSponsor=no and ShoeSponsor=yes groups
# Also set random_state=1 so we get the same sample each time we run. This is useful 
# for reproducing the results each time we run.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

#print("\nTraining data:\n", pd.concat([X_train, y_train], axis=1))
#print("\nTest data:\n", pd.concat([X_test, y_test], axis=1))

print("\nTarget feature ShoeSponsor total dataset counts:\n\n", y.value_counts())
print("\nTraining data ShoeSponsor counts:\n", y_train.value_counts())
print("\nTest data ShoeSponsor counts:\n", y_test.value_counts())
# Out:
# Target feature ShoeSponsor total dataset counts:
#
#  ShoeSponsor
# no     16
# yes    14
# Name: count, dtype: int64
#
# Training data ShoeSponsor counts:
#  ShoeSponsor
# no     11
# yes    10
# Name: count, dtype: int64
#
# Test data ShoeSponsor counts:
#  ShoeSponsor
# no     5
# yes    4
# Name: count, dtype: int64

# %%
#Lets make the ShoeSponsor unbalanced
df['ShoeSponsor_Unbalanced'] = ['yes']*30
df
# Out:
#     ID Position  Height  Weight  SponsorshipEarnings ShoeSponsor CareerStage  \
# 0    1  forward     192     218                  561         yes     veteran
# 1    2   center     218     251                   60          no  mid-career
# 2    3  forward     197     221                 1312          no      rookie
# 3    4  forward     192     219                 1359          no      rookie
# 4    5  forward     198     223                  362         yes     veteran
# 5    6    guard     166     188                 1536         yes      rookie
# 6    7  forward     195     221                  694          no     veteran
# 7    8    guard     182     199                 1678         yes      rookie
# 8    9    guard     189     199                  385         yes  mid-career
# 9   10  forward     205     232                 1416          no      rookie
# 10  11   center     206     246                  314          no  mid-career
# 11  12    guard     185     207                 1497         yes      rookie
# 12  13    guard     172     183                 1383         yes      rookie
# 13  14    guard     169     183                 1034         yes      rookie
# 14  15    guard     185     197                  178         yes  mid-career
# 15  16  forward     215     232                  434          no  mid-career
# 16  17    guard     158     184                  162         yes     veteran
# 17  18    guard     190     207                  648         yes  mid-career
# 18  19   center     195     235                  481          no  mid-career
# 19  20    guard     192     200                  427         yes  mid-career
# 20  21  forward     202     220                  542          no  mid-career
# 21  22  forward     184     213                   12          no  mid-career
# 22  23  forward     190     215                 1179          no      rookie
# 23  24    guard     178     193                 1078          no      rookie
# 24  25    guard     185     200                  213         yes  mid-career
# 25  26  forward     191     218                 1855          no      rookie
# 26  27   center     196     235                   47          no     veteran
# 27  28  forward     198     221                 1409          no      rookie
# 28  29   center     207     247                 1065          no     veteran
# 29  30   center     201     244                 1111         yes  mid-career
#
#     Age     quantile_ex_q4   quantile_ex_q10 ShoeSponsor_Unbalanced
# 0    29    (367.75, 671.0]    (518.0, 671.0]                    yes
# 1    35   (11.999, 367.75]     (11.0, 152.0]                    yes
# 2    22   (671.0, 1347.25]  (1219.0, 1388.0]                    yes
# 3    22  (1347.25, 1855.0]  (1219.0, 1388.0]                    yes
# 4    29   (11.999, 367.75]    (294.0, 414.0]                    yes
# 5    21  (1347.25, 1855.0]  (1501.0, 1855.0]                    yes
# 6    25   (671.0, 1347.25]   (671.0, 1070.0]                    yes
# 7    21  (1347.25, 1855.0]  (1501.0, 1855.0]                    yes
# 8    27    (367.75, 671.0]    (294.0, 414.0]                    yes
# 9    24  (1347.25, 1855.0]  (1388.0, 1501.0]                    yes
# 10   29   (11.999, 367.75]    (294.0, 414.0]                    yes
# 11   23  (1347.25, 1855.0]  (1388.0, 1501.0]                    yes
# 12   24  (1347.25, 1855.0]  (1219.0, 1388.0]                    yes
# 13   24   (671.0, 1347.25]   (671.0, 1070.0]                    yes
# 14   29   (11.999, 367.75]    (152.0, 294.0]                    yes
# 15   30    (367.75, 671.0]    (414.0, 518.0]                    yes
# 16   29   (11.999, 367.75]    (152.0, 294.0]                    yes
# 17   27    (367.75, 671.0]    (518.0, 671.0]                    yes
# 18   28    (367.75, 671.0]    (414.0, 518.0]                    yes
# 19   32    (367.75, 671.0]    (414.0, 518.0]                    yes
# 20   31    (367.75, 671.0]    (518.0, 671.0]                    yes
# 21   32   (11.999, 367.75]     (11.0, 152.0]                    yes
# 22   22   (671.0, 1347.25]  (1070.0, 1219.0]                    yes
# 23   21   (671.0, 1347.25]  (1070.0, 1219.0]                    yes
# 24   31   (11.999, 367.75]    (152.0, 294.0]                    yes
# 25   19  (1347.25, 1855.0]  (1501.0, 1855.0]                    yes
# 26   32   (11.999, 367.75]     (11.0, 152.0]                    yes
# 27   22  (1347.25, 1855.0]  (1388.0, 1501.0]                    yes
# 28   27   (671.0, 1347.25]   (671.0, 1070.0]                    yes
# 29   25   (671.0, 1347.25]  (1070.0, 1219.0]                    yes

# %%
df.loc[26:29, 'ShoeSponsor_Unbalanced'] = ['no'] * 4
df
# Out:
#     ID Position  Height  Weight  SponsorshipEarnings ShoeSponsor CareerStage  \
# 0    1  forward     192     218                  561         yes     veteran
# 1    2   center     218     251                   60          no  mid-career
# 2    3  forward     197     221                 1312          no      rookie
# 3    4  forward     192     219                 1359          no      rookie
# 4    5  forward     198     223                  362         yes     veteran
# 5    6    guard     166     188                 1536         yes      rookie
# 6    7  forward     195     221                  694          no     veteran
# 7    8    guard     182     199                 1678         yes      rookie
# 8    9    guard     189     199                  385         yes  mid-career
# 9   10  forward     205     232                 1416          no      rookie
# 10  11   center     206     246                  314          no  mid-career
# 11  12    guard     185     207                 1497         yes      rookie
# 12  13    guard     172     183                 1383         yes      rookie
# 13  14    guard     169     183                 1034         yes      rookie
# 14  15    guard     185     197                  178         yes  mid-career
# 15  16  forward     215     232                  434          no  mid-career
# 16  17    guard     158     184                  162         yes     veteran
# 17  18    guard     190     207                  648         yes  mid-career
# 18  19   center     195     235                  481          no  mid-career
# 19  20    guard     192     200                  427         yes  mid-career
# 20  21  forward     202     220                  542          no  mid-career
# 21  22  forward     184     213                   12          no  mid-career
# 22  23  forward     190     215                 1179          no      rookie
# 23  24    guard     178     193                 1078          no      rookie
# 24  25    guard     185     200                  213         yes  mid-career
# 25  26  forward     191     218                 1855          no      rookie
# 26  27   center     196     235                   47          no     veteran
# 27  28  forward     198     221                 1409          no      rookie
# 28  29   center     207     247                 1065          no     veteran
# 29  30   center     201     244                 1111         yes  mid-career
#
#     Age     quantile_ex_q4   quantile_ex_q10 ShoeSponsor_Unbalanced
# 0    29    (367.75, 671.0]    (518.0, 671.0]                    yes
# 1    35   (11.999, 367.75]     (11.0, 152.0]                    yes
# 2    22   (671.0, 1347.25]  (1219.0, 1388.0]                    yes
# 3    22  (1347.25, 1855.0]  (1219.0, 1388.0]                    yes
# 4    29   (11.999, 367.75]    (294.0, 414.0]                    yes
# 5    21  (1347.25, 1855.0]  (1501.0, 1855.0]                    yes
# 6    25   (671.0, 1347.25]   (671.0, 1070.0]                    yes
# 7    21  (1347.25, 1855.0]  (1501.0, 1855.0]                    yes
# 8    27    (367.75, 671.0]    (294.0, 414.0]                    yes
# 9    24  (1347.25, 1855.0]  (1388.0, 1501.0]                    yes
# 10   29   (11.999, 367.75]    (294.0, 414.0]                    yes
# 11   23  (1347.25, 1855.0]  (1388.0, 1501.0]                    yes
# 12   24  (1347.25, 1855.0]  (1219.0, 1388.0]                    yes
# 13   24   (671.0, 1347.25]   (671.0, 1070.0]                    yes
# 14   29   (11.999, 367.75]    (152.0, 294.0]                    yes
# 15   30    (367.75, 671.0]    (414.0, 518.0]                    yes
# 16   29   (11.999, 367.75]    (152.0, 294.0]                    yes
# 17   27    (367.75, 671.0]    (518.0, 671.0]                    yes
# 18   28    (367.75, 671.0]    (414.0, 518.0]                    yes
# 19   32    (367.75, 671.0]    (414.0, 518.0]                    yes
# 20   31    (367.75, 671.0]    (518.0, 671.0]                    yes
# 21   32   (11.999, 367.75]     (11.0, 152.0]                    yes
# 22   22   (671.0, 1347.25]  (1070.0, 1219.0]                    yes
# 23   21   (671.0, 1347.25]  (1070.0, 1219.0]                    yes
# 24   31   (11.999, 367.75]    (152.0, 294.0]                    yes
# 25   19  (1347.25, 1855.0]  (1501.0, 1855.0]                    yes
# 26   32   (11.999, 367.75]     (11.0, 152.0]                     no
# 27   22  (1347.25, 1855.0]  (1388.0, 1501.0]                     no
# 28   27   (671.0, 1347.25]   (671.0, 1070.0]                     no
# 29   25   (671.0, 1347.25]  (1070.0, 1219.0]                     no

# %%
#Random sampling on the dataset with unbalanced ShoeSponsor
features = df.columns[df.columns != 'ShoeSponsor_Unbalanced']

X = df[features]
y = df.ShoeSponsor_Unbalanced

#print("\nDescriptive features in X:\n", X)
#print("\nTarget feature in y:\n", y)

# Random sample from full df, keep 70% sample for train and remaining 30% sample for test
# If want to always get the same sample, set random_state=1.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

#print("\nTraining data:\n", pd.concat([X_train, y_train], axis=1))
#print("\nTest data:\n", pd.concat([X_test, y_test], axis=1))

print("\nTarget feature ShoeSponsor_Unbalanced total dataset counts:\n\n", y.value_counts())
print("\nTraining data ShoeSponsor_Unbalanced counts:\n", y_train.value_counts())
print("\nTest data ShoeSponsor_Unbalanced counts:\n", y_test.value_counts())
# Out:
# Target feature ShoeSponsor_Unbalanced total dataset counts:
#
#  ShoeSponsor_Unbalanced
# yes    26
# no      4
# Name: count, dtype: int64
#
# Training data ShoeSponsor_Unbalanced counts:
#  ShoeSponsor_Unbalanced
# yes    17
# no      4
# Name: count, dtype: int64
#
# Test data ShoeSponsor_Unbalanced counts:
#  ShoeSponsor_Unbalanced
# yes    9
# Name: count, dtype: int64

# %%
# Stratified sampling
features = df.columns[df.columns != 'ShoeSponsor_Unbalanced']

X = df[features]
y = df.ShoeSponsor_Unbalanced

#print("\nDescriptive features in X:\n", X)
#print("\nTarget feature in y:\n", y)

# Stratify sample wrt column ShoeSponsor_Unbalanced (stratify=y) so the train/test samples have a distribution 
# representative of the full sample for the ShoeSponsor_Unbalanced=no and ShoeSponsor_Unbalanced=yes groups
# Also set random_state=1 so we get the same sample each time we run. This is useful 
# for reproducing the results each time we run.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

#print("\nTraining data:\n", pd.concat([X_train, y_train], axis=1))
#print("\nTest data:\n", pd.concat([X_test, y_test], axis=1))

print("\nTarget feature ShoeSponsor_Unbalanced total dataset counts:\n", y.value_counts())
print("\nTraining data ShoeSponsor_Unbalanced counts:\n", y_train.value_counts())
print("\nTest data ShoeSponsor_Unbalanced counts:\n", y_test.value_counts())
# Out:
# Target feature ShoeSponsor_Unbalanced total dataset counts:
#  ShoeSponsor_Unbalanced
# yes    26
# no      4
# Name: count, dtype: int64
#
# Training data ShoeSponsor_Unbalanced counts:
#  ShoeSponsor_Unbalanced
# yes    18
# no      3
# Name: count, dtype: int64
#
# Test data ShoeSponsor_Unbalanced counts:
#  ShoeSponsor_Unbalanced
# yes    8
# no     1
# Name: count, dtype: int64
